# %%
import pandas as pd
from sqlalchemy import create_engine

# Connection string
engine = create_engine(
    "postgresql://postgres:botbpatel@localhost:5432/botb"
)

# Test connection
df_runs = pd.read_sql("SELECT * FROM runs LIMIT 5;", engine)
df_runs.head()
# Out:
#    id                  timestamp company_id     product_id           feature  \
# 0   1 2026-03-12 23:22:51.933389     adidas  running_shoes  boost cushioning
# 1   2 2026-03-12 23:22:55.229068     adidas  running_shoes  boost cushioning
# 2   3 2026-03-12 23:22:58.486338     adidas  running_shoes  boost cushioning
# 3   4 2026-03-12 23:23:02.183008     adidas  running_shoes       lightweight
# 4   5 2026-03-12 23:23:06.063185     adidas  running_shoes       lightweight
#
#      constraint_text model_id model_name provider  search_enabled  run_number  \
# 0         under $220  gpt_4_1    gpt-4.1   openai            True           1
# 1  for long distance  gpt_4_1    gpt-4.1   openai            True           1
# 2      for beginners  gpt_4_1    gpt-4.1   openai            True           1
# 3         under $220  gpt_4_1    gpt-4.1   openai            True           1
# 4  for long distance  gpt_4_1    gpt-4.1   openai            True           1
#
# ...

# %%
## Right now, we've data from the OPENAI only...but once we've the gemini keys, we can have data
## from multiple ai models.

# %%
query = """
SELECT r.company_id, rec.product_name
FROM runs r
JOIN recommendations rec ON r.id = rec.run_id
"""

df = pd.read_sql(query, engine)

df.groupby(["company_id", "product_name"]).size()
# Out:
# company_id  product_name
# adidas      Adidas Adizero Adios Pro 4                     2
#             Adidas Adizero Boston 12                       1
#             Adidas Adizero Boston 13                       2
#             Adidas Adizero EVO SL                          3
#             Adidas Adizero EVO SL                          1
#             Adidas Adizero SL2                             2
#             Adidas Boston 13                               1
#             Adidas Duramo 10                               1
#             Adidas Hyperboost Edge                         1
#             Adidas Questar 3                               1
#             Adidas Solarboost 3                            1
#             Adidas Supernova Rise (or Rise 2)              1
#             Adidas Supernova+                              1
#             Adidas Ultraboost 1.0 (Ultraboost original)    1
#             Adidas Ultraboost 21                           1
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connection string
engine = create_engine(
    "postgresql://postgres:botbpatel@localhost:5432/botb"
)

# Test connection
df_runs = pd.read_sql("SELECT * FROM runs LIMIT 5;", engine)
df_runs.head()
